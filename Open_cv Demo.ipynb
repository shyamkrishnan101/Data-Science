# %%
# !pip install opencv-python
# Out:
# Collecting opencv-python
#   Using cached https://files.pythonhosted.org/packages/70/a8/e52a82936be6d5696fb06c78450707c26dc13df91bb6bf49583bb9abbaa0/opencv_python-4.5.1.48-cp37-cp37m-win_amd64.whl
# Requirement already satisfied: numpy>=1.14.5 in c:\users\skrishnan\appdata\local\continuum\anaconda3\lib\site-packages (from opencv-python) (1.16.5)
# Installing collected packages: opencv-python
# Successfully installed opencv-python-4.5.1.48
# ERROR: Error checking for conflicts.
# Traceback (most recent call last):
#   File "C:\Users\skrishnan\AppData\Local\Continuum\anaconda3\lib\site-packages\pip\_vendor\pkg_resources\__init__.py", line 3012, in _dep_map
#     return self.__dep_map
#   File "C:\Users\skrishnan\AppData\Local\Continuum\anaconda3\lib\site-packages\pip\_vendor\pkg_resources\__init__.py", line 2806, in __getattr__
#     raise AttributeError(attr)
# AttributeError: _DistInfoDistribution__dep_map
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "C:\Users\skrishnan\AppData\Local\Continuum\anaconda3\lib\site-packages\pip\_vendor\pkg_resources\__init__.py", line 3003, in _parsed_pkg_info
#     return self._pkg_info
#   File "C:\Users\skrishnan\AppData\Local\Continuum\anaconda3\lib\site-packages\pip\_vendor\pkg_resources\__init__.py", line 2806, in __getattr__
#     raise AttributeError(attr)
# AttributeError: _pkg_info
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "C:\Users\skrishnan\AppData\Local\Continuum\anaconda3\lib\site-packages\pip\_internal\commands\install.py", line 517, in _warn_about_conflicts
#     package_set, _dep_info = check_install_conflicts(to_install)
#   File "C:\Users\skrishnan\AppData\Local\Continuum\anaconda3\lib\site-packages\pip\_internal\operations\check.py", line 110, in check_install_conflicts
#     package_set, _ = create_package_set_from_installed()
#   File "C:\Users\skrishnan\AppData\Local\Continuum\anaconda3\lib\site-packages\pip\_internal\operations\check.py", line 49, in create_package_set_from_installed
#     package_set[name] = PackageDetails(dist.version, dist.requires())
#   File "C:\Users\skrishnan\AppData\Local\Continuum\anaconda3\lib\site-packages\pip\_vendor\pkg_resources\__init__.py", line 2727, in requires
#     dm = self._dep_map
#   File "C:\Users\skrishnan\AppData\Local\Continuum\anaconda3\lib\site-packages\pip\_vendor\pkg_resources\__init__.py", line 3014, in _dep_map
#     self.__dep_map = self._compute_dependencies()
#   File "C:\Users\skrishnan\AppData\Local\Continuum\anaconda3\lib\site-packages\pip\_vendor\pkg_resources\__init__.py", line 3023, in _compute_dependencies
#     for req in self._parsed_pkg_info.get_all('Requires-Dist') or []:
#   File "C:\Users\skrishnan\AppData\Local\Continuum\anaconda3\lib\site-packages\pip\_vendor\pkg_resources\__init__.py", line 3005, in _parsed_pkg_info
#     metadata = self.get_metadata(self.PKG_INFO)
#   File "C:\Users\skrishnan\AppData\Local\Continuum\anaconda3\lib\site-packages\pip\_vendor\pkg_resources\__init__.py", line 1419, in get_metadata
#     value = self._get(self._fn(self.egg_info, name))
#   File "C:\Users\skrishnan\AppData\Local\Continuum\anaconda3\lib\site-packages\pip\_vendor\pkg_resources\__init__.py", line 1607, in _get
#     with open(path, 'rb') as stream:
# FileNotFoundError: [Errno 2] No such file or directory: 'c:\\users\\skrishnan\\appdata\\local\\continuum\\anaconda3\\lib\\site-packages\\google_pasta-0.2.0.dist-info\\METADATA'

# %%
#!pip freeze
# Out:
# absl-py==0.10.0
# alabaster==0.7.12
# anaconda-client==1.7.2
# anaconda-navigator==1.9.7
# anaconda-project==0.8.3
# appdirs==1.4.4
# asn1crypto==1.0.1
# astroid==2.3.1
# astropy==4.0
# astunparse==1.6.3
# atomicwrites==1.3.0
# attr==0.3.1
# attrs==19.2.0
# audioread==2.1.9
# Babel==2.7.0
# backcall==0.1.0
# backports.functools-lru-cache==1.5
# backports.os==0.1.1
# backports.shutil-get-terminal-size==1.0.0
# backports.tempfile==1.0
# backports.weakref==1.0.post1
# beautifulsoup4==4.8.0
# bitarray==1.0.1
# bkcharts==0.2
# bleach==3.1.0
# bokeh==1.3.4
# boto==2.49.0
# Bottleneck==1.2.1
# bpemb==0.3.2
# certifi==2019.9.11
# cffi==1.12.3
# chardet==3.0.4
# Click==7.0
# cloudpickle==1.2.2
# clyent==1.2.2
# colorama==0.4.1
# comtypes==1.1.7
# conda==4.7.12
# conda-build==3.18.9
# conda-package-handling==1.6.0
# conda-verify==3.4.2
# confuse==1.0.0
# contextlib2==0.6.0
# cryptography==2.7
# cssselect==1.1.0
# cycler==0.10.0
# Cython==0.29.14
# cytoolz==0.10.0
# dask==2.5.2
# decorator==4.4.0
# defusedxml==0.6.0
# Deprecated==1.2.10
# distributed==2.5.2
# docutils==0.15.2
# entrypoints==0.3
# et-xmlfile==1.0.1
# fastcache==1.1.0
# filelock==3.0.12
# flair==0.6.1.post1
# Flask==1.1.1
# fsspec==0.5.2
# ftfy==5.8
# future==0.17.1
# gast==0.3.3
# gdown==3.12.2
# gensim==3.8.3
# gevent==1.4.0
# glob2==0.7
# google-pasta==0.2.0
# greenlet==0.4.15
# grpcio==1.32.0
# h5py==2.9.0
# HeapDict==1.0.1
# html5lib==1.0.1
# htmlmin==0.1.12
# hyperopt==0.2.5
# idna==2.8
# imageio==2.6.0
# imagesize==1.1.0
# imbalanced-learn==0.7.0
# importlib-metadata==0.23
# ipykernel==5.1.2
# ipython==7.8.0
# ipython-genutils==0.2.0
# ipywidgets==7.5.1
# isort==4.3.21
# itsdangerous==1.1.0
# Janome==0.4.1
# jdcal==1.4.1
# jedi==0.15.1
# Jinja2==2.11.1
# joblib==0.14.1
# json5==0.8.5
# jsonschema==3.0.2
# jupyter==1.0.0
# jupyter-client==5.3.3
# jupyter-console==6.0.0
# jupyter-core==4.5.0
# jupyterlab==1.1.4
# jupyterlab-server==1.0.6
# kaggle==1.5.6
# Keras-Preprocessing==1.1.2
# keyring==18.0.0
# kiwisolver==1.1.0
# konoha==4.6.2
# langdetect==1.0.8
# lazy-object-proxy==1.4.2
# libarchive-c==2.8
# librosa==0.8.0
# llvmlite==0.29.0
# locket==0.2.0
# lxml==4.4.1
# Markdown==3.3.1
# markdown2==2.3.10
# MarkupSafe==1.1.1
# matplotlib==3.1.1
# mccabe==0.6.1
# menuinst==1.4.16
# missingno==0.4.2
# mistune==0.8.4
# mkl-fft==1.0.14
# mkl-random==1.1.0
# mkl-service==2.3.0
# mock==3.0.5
# more-itertools==7.2.0
# mpld3==0.3
# mpmath==1.1.0
# msgpack==0.6.1
# multipledispatch==0.6.0
# navigator-updater==0.2.1
# nbconvert==5.6.0
# nbformat==4.4.0
# networkx==2.3
# nltk==3.4.5
# nose==1.3.7
# notebook==6.1.4
# numba==0.45.1
# numexpr==2.7.0
# numpy==1.16.5
# numpydoc==0.9.1
# olefile==0.46
# openpyxl==3.0.0
# opt-einsum==3.3.0
# overrides==3.0.0
# packaging==19.2
# pandas==0.25.3
# pandas-profiling==2.5.0
# pandocfilters==1.4.2
# parso==0.5.1
# partd==1.0.0
# path.py==12.0.1
# pathlib2==2.3.5
# patsy==0.5.1
# pep8==1.7.1
# phik==0.9.9
# pickleshare==0.7.5
# Pillow==6.2.0
# pkginfo==1.5.0.1
# pluggy==0.13.0
# ply==3.11
# pooch==1.3.0
# prometheus-client==0.7.1
# prompt-toolkit==2.0.10
# protobuf==3.13.0
# psutil==5.6.3
# py==1.8.0
# pyasn1-modules==0.2.8
# pycodestyle==2.5.0
# pycosat==0.6.3
# pycparser==2.19
# pycrypto==2.6.1
# pycurl==7.43.0.3
# pyflakes==2.1.1
# Pygments==2.4.2
# pylint==2.4.2
# pyodbc==4.0.27
# pyOpenSSL==19.0.0
# pyparsing==2.4.2
# pyquery==1.4.3
# pyreadline==2.1
# pyrsistent==0.15.4
# PySocks==1.7.1
# pytest==5.2.1
# pytest-arraydiff==0.3
# pytest-astropy==0.5.0
# pytest-doctestplus==0.4.0
# pytest-openfiles==0.4.0
# pytest-pylint==0.15.0
# pytest-remotedata==0.3.2
# python-dateutil==2.8.0
# python-slugify==4.0.0
# pytz==2019.3
# PyWavelets==1.0.3
# pywin32==223
# pywinpty==0.5.5
# PyYAML==5.1.2
# pyzmq==18.1.0
# QtAwesome==0.6.0
# qtconsole==4.5.5
# QtPy==1.9.0
# readtime==1.1.1
# regex==2020.10.11
# requests==2.22.0
# resampy==0.2.2
# rope==0.14.0
# ruamel-yaml==0.15.46
# sacremoses==0.0.43
# scikit-image==0.15.0
# scikit-learn==0.24.0
# scipy==1.4.1
# seaborn==0.9.0
# segtok==1.5.10
# Send2Trash==1.5.0
# sentencepiece==0.1.91
# simplegeneric==0.8.1
# singledispatch==3.4.0.3
# six==1.12.0
# smart-open==3.0.0
# snowballstemmer==2.0.0
# sortedcollections==1.1.2
# sortedcontainers==2.1.0
# SoundFile==0.10.3.post1
# soupsieve==1.9.3
# Sphinx==2.2.0
# sphinxcontrib-applehelp==1.0.1
# sphinxcontrib-devhelp==1.0.1
# sphinxcontrib-htmlhelp==1.0.2
# sphinxcontrib-jsmath==1.0.1
# sphinxcontrib-qthelp==1.0.2
# sphinxcontrib-serializinghtml==1.1.3
# sphinxcontrib-websupport==1.1.2
# spyder==3.3.6
# spyder-kernels==0.5.2
# SQLAlchemy==1.3.9
# sqlitedict==1.7.0
# statsmodels==0.10.1
# sympy==1.4
# tables==3.5.2
# tabulate==0.8.7
# tangled-up-in-unicode==0.0.3
# tblib==1.4.0
# tensorboard==2.3.0
# tensorboard-plugin-wit==1.7.0
# tensorflow==2.3.1
# tensorflow-estimator==2.3.0
# termcolor==1.1.0
# terminado==0.8.2
# testpath==0.4.2
# text-unidecode==1.3
# threadpoolctl==2.1.0
# tokenizers==0.8.1rc2
# toolz==0.10.0
# torch==1.6.0+cpu
# torchvision==0.7.0+cpu
# tornado==6.0.3
# tqdm==4.42.0
# traitlets==4.3.3
# transformers==3.3.1
# unicodecsv==0.14.1
# urllib3==1.24.2
# visions==0.2.2
# wcwidth==0.1.7
# webencodings==0.5.1
# Werkzeug==0.16.0
# widgetsnbextension==3.5.1
# win-inet-pton==1.1.0
# win-unicode-console==0.5
# wincertstore==0.2
# wrapt==1.11.2
# xlrd==1.2.0
# XlsxWriter==1.2.1
# xlwings==0.15.10
# xlwt==1.3.0
# zict==1.0.0
# zipp==0.6.0

# %%
import cv2
import sys

# %%
# Get user supplied values
imagePath = "Decent Model - Normal_Moment.jpg"
#imagepath = sys.argv[1]
cascPath = "haarcascade_mcs_mouth.xml"
#cascPath = "haarcascade_frontalface_default.xml"
#cascPath = sys.argv[2]

# %%
# Create the haar cascade
mouthCascade = cv2.CascadeClassifier(cascPath)

# %%
# Read the image
image = cv2.imread(imagePath)
gray = cv2.cvtColor(image, cv2.COLOR_BGR2GRAY)

# %%
# Detect faces in the image
mouth = mouthCascade.detectMultiScale(gray,1.5,10)

# %%
# Draw rectangle around the faces
for (x, y, w, h) in mouth:
    cv2.rectangle(image, (x, y), (x+w, y+h), (255, 0, 0), 1)

# %%
# Display the output
cv2.imshow('Mouth Found', image)
cv2.waitKey()
# Out:
# -1

# %%
cv2.destroyAllWindows()
